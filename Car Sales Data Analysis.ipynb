# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd


df = pd.read_csv('Car_sales.csv')

# %%
# Count car model sales

model_counts = df['Model'].value_counts()

# %%
print(model_counts)
# Out:
# Model
# Neon       2
# Integra    1
# CL         1
# TL         1
# A4         1
#           ..
# V40        1
# S70        1
# V70        1
# C70        1
# S80        1
# Name: count, Length: 156, dtype: int64

# %%
# Find the top sellers

top_10_models = model_counts.head(10)
print(top_10_models)
# Out:
# Model
# Neon       2
# Integra    1
# CL         1
# TL         1
# A4         1
# A6         1
# A8         1
# 323i       1
# 328i       1
# 528i       1
# Name: count, dtype: int64

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------------- -------------------- 3.9/8.1 MB 19.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 24.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 28.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------------------------------------- -- 6.6/7.0 MB 31.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 29.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Visualize the top sellers

# You can create a bar chart to visualize the results using Matplotlib


import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
top_10_models.plot(kind='bar')
plt.title('Top 10 Best-Selling Car Models')
plt.xlabel('Car Model')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
