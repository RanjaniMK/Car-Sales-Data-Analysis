# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importing and exploring data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("Car_sales.csv")

# Display the first few rows
print(df.head())
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
# Understanding the structure of our dataset

# Get basic information about the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
# Handling missing value
# 1. Remove rows where __year_resale_value  is missing (your main variable)
df = df.dropna(subset=['__year_resale_value'])

# %%
print(df.isnull().sum())
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     2
# Engine_size            1
# Horsepower             1
# Wheelbase              1
# Width                  1
# Length                 1
# Curb_weight            2
# Fuel_capacity          1
# Fuel_efficiency        2
# Latest_Launch          0
# Power_perf_factor      2
# dtype: int64

# %%
# 2. Fill numerical columns with median (handles price outliers)
df['Price_in_thousands'].fillna(df['Price_in_thousands'].median(), inplace=True)
# Out:
# C:\Users\Ranjani M K\AppData\Local\Temp\ipykernel_27076\2085027797.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price_in_thousands'].fillna(df['Price_in_thousands'].median(), inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            1
# Horsepower             1
# Wheelbase              1
# Width                  1
# Length                 1
# Curb_weight            2
# Fuel_capacity          1
# Fuel_efficiency        2
# Latest_Launch          0
# Power_perf_factor      2
# dtype: int64

# %%
# Handling outliers

df['Horsepower'].fillna(df['Horsepower'].median(), inplace=True)
# Out:
# C:\Users\Ranjani M K\AppData\Local\Temp\ipykernel_27076\3363390470.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Horsepower'].fillna(df['Horsepower'].median(), inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            1
# Horsepower             0
# Wheelbase              1
# Width                  1
# Length                 1
# Curb_weight            2
# Fuel_capacity          1
# Fuel_efficiency        2
# Latest_Launch          0
# Power_perf_factor      2
# dtype: int64

# %%
#Fill missing numbers with the MIDDLE value (median)
print("\n" + "="*50)
print(" Fill missing numbers with median")
print("="*50)

# List of number columns to fix
number_columns = [
    'Engine_size',
    'Wheelbase', 
    'Width',
    'Length',
    'Curb_weight',
    'Fuel_capacity',
    'Fuel_efficiency',
    'Power_perf_factor',
    
]

# Fill each column with its middle value
for column in number_columns:
    if column in df.columns:  # Check if column exists
        middle_value = df[column].median()
        df[column] = df[column].fillna(middle_value)
        print(f"✓ Fixed {column}")

# Step 4: Fill missing text with 'Unknown'
print("\n" + "="*50)
print(" Fill missing text with 'Unknown'")
print("="*50)

text_columns = ['Vehicle_type', 'Model', 'Manufacturer']

for column in text_columns:
    if column in df.columns:
        df[column] = df[column].fillna('Unknown')
        print(f"✓ Fixed {column}")

# Step 5: Check if all fixed!
print("\n" + "="*50)
print(" Final check - Any missing values left?")
print("="*50)
print(df.isnull().sum())

if df.isnull().sum().sum() == 0:
    print("\n✅ Success! No missing values!")
else:
    print("\n⚠️ Some values still missing")

# Step 6: Save the clean data
df.to_excel('car_sales_clean.xlsx', index=False)
print("\n💾 Clean data saved as 'car_sales_clean.xlsx'")

print("\n" + "="*50)
print("ALL DONE! 🎉")
print("="*50)
# Out:
# ...
#  Fill missing numbers with median
# ...
# ✓ Fixed Engine_size
# ✓ Fixed Wheelbase
# ✓ Fixed Width
# ✓ Fixed Length
# ✓ Fixed Curb_weight
# ✓ Fixed Fuel_capacity
# ✓ Fixed Fuel_efficiency
# ✓ Fixed Power_perf_factor
#
# ...
#  Fill missing text with 'Unknown'
# ...
# ✓ Fixed Vehicle_type
# ✓ Fixed Model
# ✓ Fixed Manufacturer
#
# ...
#  Final check - Any missing values left?
# ...
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# dtype: int64
#
# ✅ Success! No missing values!
#
# 💾 Clean data saved as 'car_sales_clean.xlsx'
#
# ...
# ALL DONE! 🎉
# ...

# %%
df=pd.read_excel("car_sales_clean.xlsx")

# %%
print(df.isnull().sum())
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# dtype: int64

# %%
# Data Cleaning and Preprocessing
# Identifying columns that need type conversion
# Conversion of the following columns to numeric types

numeric_columns = [
    'Sales_in_thousands', '__year_resale_value','Price_in_thousands', 'Engine_size', 
    'Horsepower', 'Wheelbase', 'Width', 'Length', 'Curb_weight', 
    'Fuel_capacity', 'Fuel_efficiency', 'Power_perf_factor'
]

for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
print(df)
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 116   Volkswagen     Golf               9.761               11.425
# 117   Volkswagen    Jetta              83.721               13.240
# 118   Volkswagen   Passat              51.102               16.725
# 119   Volkswagen   Cabrio               9.569               16.575
# 120   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger              21.500          1.8         140      101.2
# ...

# %%
# Convert 'Latest_Launch' to datetime type

import pandas as pd

# Read the original Excel file again
df = pd.read_excel('car_sales_clean.xlsx')

# Check the original values before conversion
print("Original Latest_Launch column:")
print(df['Latest_Launch'].head(20))
print("\nData type:", df['Latest_Launch'].dtype)
print("\nUnique values sample:")
print(df['Latest_Launch'].unique()[:20])

# Try conversion and see which values failed
df['Latest_Launch_converted'] = pd.to_datetime(df['Latest_Launch'], errors='coerce')

# Find rows where conversion failed
failed_conversions = df[df['Latest_Launch_converted'].isna() & df['Latest_Launch'].notna()]
print("\n--- Values that failed to convert ---")
print(failed_conversions[['Latest_Launch']])
print("\nFailed values:")
print(failed_conversions['Latest_Launch'].unique())
# Out:
# Original Latest_Launch column:
# 0     02-02-2012
# 1     06-03-2011
# 2     01-04-2012
# 3     03-10-2011
# 4     10-08-2011
# 5     08-09-2011
# 6      2/27/2012
# 7      1/29/2012
# 8     04-04-2011
# 9     11-02-2011
# 10    09-03-2011
# 11     3/23/2012
# 12     7/23/2011
# 13     2/23/2012
# 14     4/29/2011
# 15    11/27/2011
# 16     9/28/2011
# 17     8/17/2011
# 18     3/19/2012
# 19     5/24/2011
# Name: Latest_Launch, dtype: object
#
# Data type: object
#
# Unique values sample:
# ['02-02-2012' '06-03-2011' '01-04-2012' '03-10-2011' '10-08-2011'
#  '08-09-2011' '2/27/2012' '1/29/2012' '04-04-2011' '11-02-2011'
#  '09-03-2011' '3/23/2012' '7/23/2011' '2/23/2012' '4/29/2011' '11/27/2011'
#  '9/28/2011' '8/17/2011' '3/19/2012' '5/24/2011']
#
# --- Values that failed to convert ---
#     Latest_Launch
# 6       2/27/2012
# 7       1/29/2012
# 11      3/23/2012
# 12      7/23/2011
# 13      2/23/2012
# ..            ...
# 115     9/25/2011
# 116     1/24/2011
# ...

# %%
print(df.isnull().sum())
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value     0
# Vehicle_type            0
# Price_in_thousands      0
# Engine_size             0
# Horsepower              0
# Wheelbase               0
# Width                   0
# Length                  0
# Curb_weight             0
# Fuel_capacity           0
# Fuel_efficiency         0
# Latest_Launch          79
# Power_perf_factor       0
# dtype: int64
